# %% [markdown]
# # Rental Index

# %%
# import libraries
import pandas as pd  
import plotly_express as px 
import numpy as np 
import pandas as pd

# %%
# read dataset
rental_index = pd.read_csv('datasets/rent_index.csv')

# %%
rental_index.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName   2015-03-31  \
# 0    102001         0    United States    country       NaN  1304.765607
# 1    394913         1     New York, NY        msa        NY  2385.219396
# 2    753899         2  Los Angeles, CA        msa        CA  1914.730864
# 3    394463         3      Chicago, IL        msa        IL  1422.672410
# 4    394514         4       Dallas, TX        msa        TX  1157.334850
#
#     2015-04-30   2015-05-31   2015-06-30   2015-07-31  ...   2022-04-30  \
# 0  1314.826253  1324.585785  1334.686343  1340.823032  ...  1900.134122
# 1  2403.753582  2421.231076  2439.382330  2448.425349  ...  2955.859223
# 2  1927.655457  1940.995475  1952.425792  1968.438708  ...  2823.035882
# 3  1435.441402  1446.702786  1470.374315  1476.787061  ...  1795.344311
# 4  1167.824303  1179.831226  1187.613051  1193.868953  ...  1740.651141
#
#     2022-05-31   2022-06-30   2022-07-31   2022-08-31   2022-09-30  \
# 0  1922.956545  1947.715930  1968.283854  1981.452792  1986.672234
# 1  3015.296055  3076.799046  3130.332141  3154.033247  3151.025599
# 2  2857.376769  2882.139364  2903.194297  2916.149142  2923.484011
# 3  1820.754624  1841.547087  1860.531252  1868.719705  1871.457472
# 4  1769.936539  1803.818103  1827.997976  1837.990096  1837.313291
#
#     2022-10-31   2022-11-30   2022-12-31   2023-01-31
# 0  1984.735689  1976.529824  1971.469353  1970.243426
# 1  3127.883766  3095.742311  3072.639223  3065.017318
# 2  2919.007841  2910.841929  2902.889391  2896.943067
# 3  1869.964119  1863.995689  1864.939703  1868.858460
# 4  1825.096163  1810.306142  1795.009792  1789.450877
#
# [5 rows x 100 columns]

# %%
# drop columns
rental_index.drop(columns=['RegionID', 'SizeRank', 'RegionType'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 rental_index.drop(columns=['RegionID', 'SizeRank', 'RegionType'], inplace=True)
#
# File c:\Users\XIX\anaconda3\envs\streamlit\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\XIX\anaconda3\envs\streamlit\lib\site-packages\pandas\core\frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File c:\Users\XIX\anaconda3\envs\streamlit\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\XIX\anaconda3\envs\streamlit\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\XIX\anaconda3\envs\streamlit\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\XIX\anaconda3\envs\streamlit\lib\site-packages\pandas\core\indexes\base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['RegionID', 'SizeRank', 'RegionType'] not found in axis"

# %%
# rename columns 
rental_index.rename(columns={'RegionName': 'region_name', 'StateName': 'state_name'}, inplace=True)

# %%
# fill for USA
rental_index.state_name.fillna('USA', inplace=True)

# %%
rental_index.head()
# Out:
#        region_name state_name   2015-03-31   2015-04-30   2015-05-31  \
# 0    United States        USA  1304.765607  1314.826253  1324.585785
# 1     New York, NY         NY  2385.219396  2403.753582  2421.231076
# 2  Los Angeles, CA         CA  1914.730864  1927.655457  1940.995475
# 3      Chicago, IL         IL  1422.672410  1435.441402  1446.702786
# 4       Dallas, TX         TX  1157.334850  1167.824303  1179.831226
#
#     2015-06-30   2015-07-31   2015-08-31   2015-09-30   2015-10-31  ...  \
# 0  1334.686343  1340.823032  1346.430177  1348.334928  1349.757326  ...
# 1  2439.382330  2448.425349  2462.016357  2468.739863  2474.215488  ...
# 2  1952.425792  1968.438708  1982.282355  1993.858844  1999.432996  ...
# 3  1470.374315  1476.787061  1483.009421  1481.020743  1474.237195  ...
# 4  1187.613051  1193.868953  1198.609530  1201.245156  1200.119952  ...
#
#     2022-04-30   2022-05-31   2022-06-30   2022-07-31   2022-08-31  \
# 0  1900.134122  1922.956545  1947.715930  1968.283854  1981.452792
# 1  2955.859223  3015.296055  3076.799046  3130.332141  3154.033247
# 2  2823.035882  2857.376769  2882.139364  2903.194297  2916.149142
# 3  1795.344311  1820.754624  1841.547087  1860.531252  1868.719705
# 4  1740.651141  1769.936539  1803.818103  1827.997976  1837.990096
#
#     2022-09-30   2022-10-31   2022-11-30   2022-12-31   2023-01-31
# 0  1986.672234  1984.735689  1976.529824  1971.469353  1970.243426
# 1  3151.025599  3127.883766  3095.742311  3072.639223  3065.017318
# 2  2923.484011  2919.007841  2910.841929  2902.889391  2896.943067
# 3  1871.457472  1869.964119  1863.995689  1864.939703  1868.858460
# 4  1837.313291  1825.096163  1810.306142  1795.009792  1789.450877
#
# [5 rows x 97 columns]

# %%
state_rental = rental_index.groupby('state_name').mean().T
# Out:
# C:\Users\XIX\AppData\Local\Temp\ipykernel_12440\2182910075.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
state_rental.head()
# Out:
# state_name           AK          AL          AR          AZ           CA  \
# 2015-03-31  1267.157818  872.117038  832.901115  893.186337  1527.244979
# 2015-04-30  1261.610863  868.766022  849.250556  901.605463  1543.930294
# 2015-05-31  1268.931475  875.207182  872.790457  906.096210  1559.483440
# 2015-06-30  1277.283320  882.438048  876.366815  910.108116  1569.420387
# 2015-07-31  1278.772928  897.332692  878.793698  911.756630  1582.395624
#
# state_name           CO           CT           DE           FL          GA  \
# 2015-03-31  1227.959543  1268.682357  1124.057876  1108.693323  875.833428
# 2015-04-30  1168.969987  1279.292914  1126.610515  1113.899635  873.975047
# 2015-05-31  1176.221844  1297.129243  1130.376621  1120.195994  907.918586
# 2015-06-30  1185.587363  1298.895608  1123.354806  1127.050729  904.474120
# 2015-07-31  1194.749835  1304.768300  1113.046347  1134.358975  915.357793
#
# state_name  ...          TN           TX          USA           UT  \
# 2015-03-31  ...  971.116659  1018.017857  1304.765607  1021.753621
# 2015-04-30  ...  974.151356  1002.181919  1314.826253  1026.618962
# 2015-05-31  ...  978.481582  1009.508076  1324.585785  1034.834187
# 2015-06-30  ...  981.630635  1015.530849  1334.686343  1039.786301
# 2015-07-31  ...  987.947260  1019.823033  1340.823032  1047.931070
#
# state_name           VA  VT           WA           WI  WV          WY
# 2015-03-31  1049.831574 NaN  1092.020416   985.170439 NaN  945.564045
# 2015-04-30  1057.432888 NaN  1100.696442   990.165904 NaN  951.603483
# 2015-05-31  1061.300156 NaN  1110.974713   998.106006 NaN  971.183893
# 2015-06-30  1067.889883 NaN  1117.912743  1004.073079 NaN  973.204574
# 2015-07-31  1071.594070 NaN  1120.882331  1004.896855 NaN  976.494914
#
# [5 rows x 51 columns]

# %%
px.line(state_rental, title='Mean Rent', template='plotly_white', height=900, width=1400, labels={'index': 'Date', 'value': 'Rent ($)'})

# %%
# filtering for states
ga_rent = state_rental.GA
pa_rent = state_rental.PA   
md_rent = state_rental.MD
usa_rent = state_rental.USA

# %%
# combining filtered states
rents = pd.concat([ga_rent, pa_rent, md_rent, usa_rent], axis=1)

# %%
px.line(rents, title='Mean Rent', labels={'index':'Years', 'value':'Rent ($)'}, template='plotly_white')

# %%
state_rental_median = rental_index.groupby('state_name').median().T
# Out:
# C:\Users\XIX\AppData\Local\Temp\ipykernel_12440\2438563661.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
px.line(state_rental_median, height=900, width=1400, labels={'index': 'Date', 'value': 'Rent ($)'}, title='Median Rent')

# %%
# filter states 
ga_rent_median = state_rental_median.GA
pa_rent_median = state_rental_median.PA   
md_rent_median = state_rental_median.MD
usa_rent_median = state_rental_median.USA

# %%
# combine filters
rents_median = pd.concat([ga_rent_median, pa_rent_median, md_rent_median, usa_rent_median], axis=1)

# %%
px.line(rents_median, labels={'index':'Years', 'value':'Rent ($)'}, template='plotly_white', title='Median Rent')

# %%
rental_index
# Out:
#          region_name state_name   2015-03-31   2015-04-30   2015-05-31  \
# 0      United States        USA  1304.765607  1314.826253  1324.585785
# 1       New York, NY         NY  2385.219396  2403.753582  2421.231076
# 2    Los Angeles, CA         CA  1914.730864  1927.655457  1940.995475
# 3        Chicago, IL         IL  1422.672410  1435.441402  1446.702786
# 4         Dallas, TX         TX  1157.334850  1167.824303  1179.831226
# ..               ...        ...          ...          ...          ...
# 533   Prineville, OR         OR          NaN          NaN          NaN
# 534       Hailey, ID         ID          NaN          NaN          NaN
# 535    Jamestown, ND         ND          NaN          NaN          NaN
# 536     Portales, NM         NM          NaN          NaN          NaN
# 537   Vermillion, SD         SD          NaN          NaN          NaN
#
#       2015-06-30   2015-07-31   2015-08-31   2015-09-30   2015-10-31  ...  \
# 0    1334.686343  1340.823032  1346.430177  1348.334928  1349.757326  ...
# 1    2439.382330  2448.425349  2462.016357  2468.739863  2474.215488  ...
# 2    1952.425792  1968.438708  1982.282355  1993.858844  1999.432996  ...
# 3    1470.374315  1476.787061  1483.009421  1481.020743  1474.237195  ...
# 4    1187.613051  1193.868953  1198.609530  1201.245156  1200.119952  ...
# ..           ...          ...          ...          ...          ...  ...
# 533          NaN          NaN          NaN          NaN          NaN  ...
# 534          NaN          NaN          NaN          NaN          NaN  ...
# 535          NaN          NaN          NaN          NaN          NaN  ...
# 536          NaN          NaN          NaN          NaN          NaN  ...
# 537          NaN          NaN          NaN          NaN          NaN  ...
#
#       2022-04-30   2022-05-31   2022-06-30   2022-07-31   2022-08-31  \
# 0    1900.134122  1922.956545  1947.715930  1968.283854  1981.452792
# 1    2955.859223  3015.296055  3076.799046  3130.332141  3154.033247
# 2    2823.035882  2857.376769  2882.139364  2903.194297  2916.149142
# 3    1795.344311  1820.754624  1841.547087  1860.531252  1868.719705
# 4    1740.651141  1769.936539  1803.818103  1827.997976  1837.990096
# ..           ...          ...          ...          ...          ...
# 533          NaN          NaN          NaN          NaN          NaN
# 534          NaN          NaN          NaN          NaN          NaN
# 535          NaN          NaN          NaN          NaN          NaN
# 536          NaN          NaN          NaN          NaN          NaN
# 537          NaN          NaN          NaN          NaN          NaN
#
#       2022-09-30   2022-10-31   2022-11-30   2022-12-31   2023-01-31
# 0    1986.672234  1984.735689  1976.529824  1971.469353  1970.243426
# 1    3151.025599  3127.883766  3095.742311  3072.639223  3065.017318
# 2    2923.484011  2919.007841  2910.841929  2902.889391  2896.943067
# 3    1871.457472  1869.964119  1863.995689  1864.939703  1868.858460
# 4    1837.313291  1825.096163  1810.306142  1795.009792  1789.450877
# ..           ...          ...          ...          ...          ...
# 533          NaN          NaN          NaN          NaN  1600.000000
# 534          NaN          NaN          NaN          NaN  2375.000000
# 535          NaN          NaN   726.483663   713.900518   689.333333
# 536          NaN          NaN          NaN          NaN   930.000000
# 537          NaN          NaN          NaN          NaN  1250.000000
#
# [538 rows x 97 columns]

# %%
px.line(rental_index.groupby('state_name').mean().pct_change(axis='columns')*100, title='Rent Percent Change by Year', template='plotly_white', labels={'state_name': 'State', 'value':'Percent Change'})
# Out:
# C:\Users\XIX\AppData\Local\Temp\ipykernel_12440\2102596915.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
px.line(state_rental.pct_change(axis='rows')*100, title='Rent Percent Change Year Over Year, by State', template='plotly_white', labels={'index': 'Year', 'value':'Percent Change'})
